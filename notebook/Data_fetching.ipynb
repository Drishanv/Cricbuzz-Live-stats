# %% [markdown]
# # **Setup (keys, imports, DB path)**

# %%
# Minimal imports
import os, sqlite3, time
from datetime import datetime
import requests
import pandas as pd

# === RapidAPI creds ===
# Option A: set env var RAPIDAPI_KEY (recommended)
# Option B: paste your key below and leave the env empty
PASTE_KEY = "f5d6786ebdmsh4c0039968cab7abp1a67efjsnc575353b1079"  # put your key here if you don't use env vars

RAPIDAPI_KEY  = os.getenv("RAPIDAPI_KEY", "").strip() or PASTE_KEY.strip()
RAPIDAPI_HOST = "cricbuzz-cricket.p.rapidapi.com"
BASE_URL      = f"https://{RAPIDAPI_HOST}"

if not RAPIDAPI_KEY:
    raise ValueError("No API key found. Set env RAPIDAPI_KEY or paste in PASTE_KEY.")

HEADERS = {
    "X-RapidAPI-Key": RAPIDAPI_KEY,
    "X-RapidAPI-Host": RAPIDAPI_HOST,
}

# === SQLite DB path (local file) ===
DB_PATH = "cricket_test.db"

# %% [markdown]
# # **Tiny helper**

# %%
def get_json(url, params=None, retries=1, timeout=12):
    for attempt in range(retries + 1):
        r = requests.get(url, headers=HEADERS, params=params or {}, timeout=timeout)
        if r.status_code == 200:
            return r.json()
        time.sleep(0.6)
    r.raise_for_status()

# %% [markdown]
# # **Tables creation**

# %%
def init_db(db_path=DB_PATH):
    ddl = """
    CREATE TABLE IF NOT EXISTS matches (
        match_id INTEGER PRIMARY KEY,
        description TEXT,
        match_type TEXT,
        status TEXT,
        start_time TEXT,
        team1 TEXT,
        team2 TEXT,
        venue TEXT
    );
    """
    with sqlite3.connect(db_path) as conn:
        conn.execute(ddl)
        conn.commit()

init_db()
print("DB ready at:", os.path.abspath(DB_PATH))
# Out:
# DB ready at: /content/cricket_test.db

# %% [markdown]
# # **Fetch recent/live/upcoming matches from RapidAPI and normalize it**

# %%
KIND = "recent"  # change to "live" or "upcoming" if you want
data = get_json(f"{BASE_URL}/matches/v1/{KIND}")

def ts(ms):
    try:
        return datetime.utcfromtimestamp(int(ms)/1000).strftime("%Y-%m-%d %H:%M:%S")
    except Exception:
        return None

rows = []
for block in data.get("typeMatches", []):
    for wrapper in block.get("seriesMatches", []):
        series = wrapper.get("seriesAdWrapper") or {}
        for m in series.get("matches", []):
            mi = (m or {}).get("matchInfo", {}) or {}
            v  = mi.get("venueInfo", {}) or {}
            rows.append({
                "match_id"   : mi.get("matchId"),
                "description": mi.get("matchDesc"),
                "match_type" : mi.get("matchFormat"),
                "status"     : mi.get("stateTitle") or mi.get("status"),
                "start_time" : ts(mi.get("startDate")),
                "team1"      : (mi.get("team1") or {}).get("teamName"),
                "team2"      : (mi.get("team2") or {}).get("teamName"),
                "venue"      : v.get("ground"),
            })

df = pd.DataFrame(rows).dropna(subset=["match_id"]).drop_duplicates(subset=["match_id"])
print(f"Parsed {len(df)} matches from '{KIND}'.")
df.head(10)
# Out:
# Parsed 67 matches from 'recent'.
# /tmp/ipython-input-254256000.py:6: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   return datetime.utcfromtimestamp(int(ms)/1000).strftime("%Y-%m-%d %H:%M:%S")
#    match_id description match_type   status           start_time  \
# 0    105786     1st ODI        ODI  RSA Won  2025-09-02 12:00:00
# 1    105794     3rd ODI        ODI  ENG Won  2025-09-07 10:00:00
# 2    105788     2nd ODI        ODI  RSA Won  2025-09-04 12:00:00
# 3    131086   6th Match        T20  AFG Won  2025-09-05 15:00:00
# 4    131092       Final        T20  PAK Won  2025-09-07 15:00:00
# 5    131070   4th Match        T20  AFG Won  2025-09-02 15:00:00
# 6    131075   5th Match        T20  PAK Won  2025-09-04 15:00:00
# 7    128919  85th Match        ODI  Abandon  2025-09-06 14:30:00
# 8    128908  84th Match        ODI  SCO Won  2025-09-04 14:30:00
# 9    128902  83rd Match        ODI  NAM Won  2025-09-02 14:30:00
#
#           team1                 team2                         venue
# 0       England          South Africa                    Headingley
# 1       England          South Africa                 The Rose Bowl
# 2  South Africa               England                        Lord's
# 3   Afghanistan  United Arab Emirates       Sharjah Cricket Stadium
# 4      Pakistan           Afghanistan       Sharjah Cricket Stadium
# 5   Afghanistan              Pakistan       Sharjah Cricket Stadium
# 6      Pakistan  United Arab Emirates       Sharjah Cricket Stadium
# 7        Canada              Scotland  Maple Leaf North-West Ground
# 8      Scotland               Namibia  Maple Leaf North-West Ground
# 9       Namibia                Canada  Maple Leaf North-West Ground

# %% [markdown]
# # **Upsert into SQlite and preview**

# %%
with sqlite3.connect(DB_PATH) as conn:
    if not df.empty:
        cols = list(df.columns)
        placeholders = ",".join(["?"] * len(cols))
        col_list = ",".join(cols)
        update_set = ",".join([f"{c}=excluded.{c}" for c in cols if c != "match_id"])
        sql = f"""
            INSERT INTO matches ({col_list})
            VALUES ({placeholders})
            ON CONFLICT(match_id) DO UPDATE SET {update_set};
        """
        conn.executemany(sql, [tuple(x) for x in df.itertuples(index=False, name=None)])
        conn.commit()

    preview = pd.read_sql_query("SELECT * FROM matches ORDER BY start_time DESC LIMIT 10;", conn)

print("Wrote rows:", len(df))
preview
# Out:
# Wrote rows: 67
#    match_id         description match_type     status           start_time  \
# 0    131735  1st Match, Group A        T20  FIJIW Won  2025-09-08 21:30:00
# 1    131741  2nd Match, Group B        T20   PNGW Won  2025-09-08 21:30:00
# 2    116774          25th Match        T20    SNP Won  2025-09-08 00:00:00
# 3    122093           2nd Match        T20    BRW Won  2025-09-07 19:00:00
# 4    116765          24th Match        T20     BR Won  2025-09-07 15:00:00
# 5    131092               Final        T20    PAK Won  2025-09-07 15:00:00
# 6    133187           4th Match        T20    Abandon  2025-09-07 14:30:00
# 7    130806               Final        T20    KBT Won  2025-09-07 13:15:00
# 8    122973            3rd T20I        T20     SL Won  2025-09-07 11:30:00
# 9    105794             3rd ODI        ODI    ENG Won  2025-09-07 10:00:00
#
#                           team1                   team2  \
# 0            Cook Islands Women              Fiji Women
# 1        Papua New Guinea Women             Japan Women
# 2   St Kitts and Nevis Patriots  Guyana Amazon Warriors
# 3  Guyana Amazon Warriors Women   Barbados Royals Women
# 4               Barbados Royals       Saint Lucia Kings
# 5                      Pakistan             Afghanistan
# 6                   Isle of Man                  Sweden
# 7             Kochi Blue Tigers    Aries Kollam Sailors
# 8                      Zimbabwe               Sri Lanka
# 9                       England            South Africa
#
#                                        venue
# 0                              Albert Park 1
# 1                              Albert Park 2
# 2                         Providence Stadium
# 3                         Providence Stadium
# 4                            Kensington Oval
# 5                    Sharjah Cricket Stadium
# 6  Cronkbourne Sports and Social Club Ground
# 7           Greenfield International Stadium
# 8                         Harare Sports Club
# 9                              The Rose Bowl

# %% [markdown]
# # **Increasing the rows count**

# %%
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", None)
pd.set_option("display.width", 1000)

# %% [markdown]
# # **Saving the test dataframe into csv**

# %%
csv_path = "sample_matches.csv"
df.to_csv(csv_path, index=False)
print("CSV saved at:", os.path.abspath(csv_path))
# Out:
# CSV saved at: /content/sample_matches.csv

# %%
pd.read_csv("sample_matches.csv")
# Out:
#     match_id                        description match_type     status           start_time                         team1                         team2                                              venue
# 0     105786                            1st ODI        ODI    RSA Won  2025-09-02 12:00:00                       England                  South Africa                                         Headingley
# 1     105794                            3rd ODI        ODI    ENG Won  2025-09-07 10:00:00                       England                  South Africa                                      The Rose Bowl
# 2     105788                            2nd ODI        ODI    RSA Won  2025-09-04 12:00:00                  South Africa                       England                                             Lord's
# 3     131086                          6th Match        T20    AFG Won  2025-09-05 15:00:00                   Afghanistan          United Arab Emirates                            Sharjah Cricket Stadium
# 4     131092                              Final        T20    PAK Won  2025-09-07 15:00:00                      Pakistan                   Afghanistan                            Sharjah Cricket Stadium
# 5     131070                          4th Match        T20    AFG Won  2025-09-02 15:00:00                   Afghanistan                      Pakistan                            Sharjah Cricket Stadium
# 6     131075                          5th Match        T20    PAK Won  2025-09-04 15:00:00                      Pakistan          United Arab Emirates                            Sharjah Cricket Stadium
# 7     128919                         85th Match        ODI    Abandon  2025-09-06 14:30:00                        Canada                      Scotland                       Maple Leaf North-West Ground
# 8     128908                         84th Match        ODI    SCO Won  2025-09-04 14:30:00                      Scotland                       Namibia                       Maple Leaf North-West Ground
# 9     128902                         83rd Match        ODI    NAM Won  2025-09-02 14:30:00                       Namibia                        Canada                       Maple Leaf North-West Ground
# 10    131119                           3rd T20I        T20   Complete  2025-09-03 12:00:00                    Bangladesh                   Netherlands               Sylhet International Cricket Stadium
# 11    122973                           3rd T20I        T20     SL Won  2025-09-07 11:30:00                      Zimbabwe                     Sri Lanka                                 Harare Sports Club
# 12    122968                           2nd T20I        T20    ZIM Won  2025-09-06 11:30:00                     Sri Lanka                      Zimbabwe                                 Harare Sports Club
# 13    122962                           1st T20I        T20     SL Won  2025-09-03 11:30:00                      Zimbabwe                     Sri Lanka                                 Harare Sports Club
# 14    133187                          4th Match        T20    Abandon  2025-09-07 14:30:00                   Isle of Man                        Sweden          Cronkbourne Sports and Social Club Ground
# 15    133176                           3rd T20I        T20    Abandon  2025-09-07 10:00:00                   Isle of Man                        Sweden          Cronkbourne Sports and Social Club Ground
# 16    133171                           2nd T20I        T20    SWE Won  2025-09-06 14:30:00                   Isle of Man                        Sweden          Cronkbourne Sports and Social Club Ground
# 17    133160                           1st T20I        T20    SWE Won  2025-09-06 10:00:00                   Isle of Man                        Sweden          Cronkbourne Sports and Social Club Ground
# 18    116765                         24th Match        T20     BR Won  2025-09-07 15:00:00               Barbados Royals             Saint Lucia Kings                                    Kensington Oval
# 19    116774                         25th Match        T20    SNP Won  2025-09-08 00:00:00   St Kitts and Nevis Patriots        Guyana Amazon Warriors                                 Providence Stadium
# 20    116759                         23rd Match        T20    GAW Won  2025-09-06 23:00:00        Trinbago Knight Riders        Guyana Amazon Warriors                                 Providence Stadium
# 21    116750                         22nd Match        T20    ABF Won  2025-09-05 23:00:00               Barbados Royals   Antigua and Barbuda Falcons                                    Kensington Oval
# 22    116741                         21st Match        T20    GAW Won  2025-09-04 23:00:00               Barbados Royals        Guyana Amazon Warriors                                    Kensington Oval
# 23    116738                         20th Match        T20    SLK Won  2025-09-03 23:00:00        Trinbago Knight Riders             Saint Lucia Kings                                 Brian Lara Stadium
# 24    111073                    Quarter Final 3        T20  LANCS Won  2025-09-06 13:30:00                          Kent                    Lancashire                              Emirates Old Trafford
# 25    111081                    Quarter Final 4        T20    SOM Won  2025-09-06 17:30:00                  Warwickshire                      Somerset                The Cooper Associates County Ground
# 26    111069                    Quarter Final 2        T20    HAM Won  2025-09-05 17:30:00                     Hampshire                        Durham                                   Riverside Ground
# 27    111061                    Quarter Final 1        T20  NHNTS Won  2025-09-03 17:30:00              Northamptonshire                        Surrey                                    Kennington Oval
# 28    132637                        Qualifier 2        T20    MRM Won  2025-09-04 14:00:00              Meerut Mavericks               Lucknow Falcons  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 29    132648                              Final        T20    KRD Won  2025-09-06 14:00:00              Meerut Mavericks                  Kashi Rudras  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 30    132632                         Eliminator        T20    LFC Won  2025-09-03 14:00:00               Lucknow Falcons         Gaur Gorakhapur Lions  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 31    132621                        Qualifier 1        T20    KRD Won  2025-09-03 09:30:00                  Kashi Rudras              Meerut Mavericks  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...
# 32    130778                         30th Match        T20    TST Won  2025-09-04 13:15:00             Calicut Globstars               Thrissur Titans                   Greenfield International Stadium
# 33    130806                              Final        T20    KBT Won  2025-09-07 13:15:00             Kochi Blue Tigers          Aries Kollam Sailors                   Greenfield International Stadium
# 34    130751                         26th Match        T20    ATR Won  2025-09-02 13:15:00       Adani Trivandrum Royals               Thrissur Titans                   Greenfield International Stadium
# 35    130784           Semi Final 1 (2nd v 3rd)        T20    AKS Won  2025-09-05 09:00:00               Thrissur Titans          Aries Kollam Sailors                   Greenfield International Stadium
# 36    130795           Semi Final 2 (1st v 4th)        T20    KBT Won  2025-09-05 13:15:00             Kochi Blue Tigers             Calicut Globstars                   Greenfield International Stadium
# 37    130773                         29th Match        T20    AKS Won  2025-09-04 09:00:00              Alleppey Ripples          Aries Kollam Sailors                   Greenfield International Stadium
# 38    130762                         28th Match        T20    KBT Won  2025-09-03 13:15:00          Aries Kollam Sailors             Kochi Blue Tigers                   Greenfield International Stadium
# 39    130756                         27th Match        T20    ATR Won  2025-09-03 09:00:00       Adani Trivandrum Royals              Alleppey Ripples                   Greenfield International Stadium
# 40    123677                     2nd Semi-Final       TEST   Complete  2025-09-04 04:00:00                     West Zone                  Central Zone                 BCCI Centre of Excellence Ground B
# 41    123672                     1st Semi-Final       TEST   Complete  2025-09-04 04:00:00                    South Zone                    North Zone                   BCCI Centre of Excellence Ground
# 42    116489                 3rd Unofficial ODI        ODI    NZA Won  2025-09-03 08:00:00                South Africa A                 New Zealand A                                LC de Villiers Oval
# 43    133066                           3rd T20I        T20   ESTW Won  2025-09-07 07:00:00          Czech Republic Women                 Estonia Women          Estonian National Cricket and Rugby Field
# 44    133055                           1st T20I        T20   ESTW Won  2025-09-06 08:00:00          Czech Republic Women                 Estonia Women          Estonian National Cricket and Rugby Field
# 45    133061                           2nd T20I        T20   ESTW Won  2025-09-06 12:30:00                 Estonia Women          Czech Republic Women          Estonian National Cricket and Rugby Field
# 46    133776                          5th Match        T20    Abandon  2025-09-03 09:30:00                  Jersey Women                  Brazil Women                           New Farnley Cricket Club
# 47    133792                          7th Match        T20   BRAW Won  2025-09-04 09:30:00                  Jersey Women                  Brazil Women                           New Farnley Cricket Club
# 48    133787                          6th Match        T20   BRAW Won  2025-09-03 14:30:00                  Brazil Women                  Jersey Women                           New Farnley Cricket Club
# 49    133798                           1st T20I        T20   JPNW Won  2025-09-05 02:00:00                   Japan Women                    Fiji Women                                      Albert Park 1
# 50    133809                           2nd T20I        T20   JPNW Won  2025-09-05 22:00:00                   Japan Women                    Fiji Women                                      Albert Park 1
# 51    131686                              Final        T20   ZIMW Won  2025-09-06 11:50:00                 Namibia Women                Zimbabwe Women                             Namibia Cricket Ground
# 52    131625                12th Match, Group A        T20   ZIMW Won  2025-09-03 11:50:00                 Nigeria Women                Zimbabwe Women                              High Performance Oval
# 53    131609                10th Match, Group A        T20   NAMW Won  2025-09-03 07:30:00                 Namibia Women            Sierra Leone Women                              High Performance Oval
# 54    131647                     2nd semi-final        T20   NAMW Won  2025-09-04 11:50:00                Tanzania Women                 Namibia Women                             Namibia Cricket Ground
# 55    131664                 3rd place play-off        T20   TANW Won  2025-09-06 07:30:00                Tanzania Women                  Uganda Women                             Namibia Cricket Ground
# 56    131675                 5th Place Play-off        T20   RWAW Won  2025-09-06 11:50:00                  Rwanda Women                   Kenya Women                              High Performance Oval
# 57    131669                 7th Place Play-off        T20   NGAW Won  2025-09-06 07:30:00                 Nigeria Women            Sierra Leone Women                              High Performance Oval
# 58    131631                     1st semi-final        T20   ZIMW Won  2025-09-04 07:30:00                  Uganda Women                Zimbabwe Women                             Namibia Cricket Ground
# 59    131653  5th Place Play-off 2nd Semi-Final        T20   RWAW Won  2025-09-04 11:50:00                  Rwanda Women            Sierra Leone Women                              High Performance Oval
# 60    131642  5th Place Play-off 1st Semi-Final        T20   KENW Won  2025-09-04 07:30:00                   Kenya Women                 Nigeria Women                              High Performance Oval
# 61    131614                11th Match, Group B        T20   UGAW Won  2025-09-03 11:50:00                   Kenya Women                  Uganda Women                             Namibia Cricket Ground
# 62    131598                 9th Match, Group B        T20   TANW Won  2025-09-03 07:30:00                Tanzania Women                  Rwanda Women                             Namibia Cricket Ground
# 63    131741                 2nd Match, Group B        T20   PNGW Won  2025-09-08 21:30:00        Papua New Guinea Women                   Japan Women                                      Albert Park 2
# 64    131735                 1st Match, Group A        T20  FIJIW Won  2025-09-08 21:30:00            Cook Islands Women                    Fiji Women                                      Albert Park 1
# 65    122093                          2nd Match        T20    BRW Won  2025-09-07 19:00:00  Guyana Amazon Warriors Women         Barbados Royals Women                                 Providence Stadium
# 66    122082                          1st Match        T20   GAWW Won  2025-09-06 18:00:00  Guyana Amazon Warriors Women  Trinbago Knight Riders Women                                 Providence Stadium
